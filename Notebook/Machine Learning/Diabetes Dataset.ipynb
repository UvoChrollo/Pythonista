# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = '../../../Gudang/diabetes.csv'
df_diabet = pd.read_csv(url)
df_diabet.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_diabet.shape
# Out:
# (768, 9)

# %%
korelasi = round(df_diabet.corr(),2)
plt.figure(figsize=(8,8))
ax = sns.heatmap(korelasi,annot=True,cmap='Wistia')
